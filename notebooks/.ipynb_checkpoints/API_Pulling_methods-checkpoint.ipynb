# %% [markdown]
# ### Step 1: Data Collection Using Spotify API

# %%
# Imports woooo!
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import collections

# %%
# Scopes to define Spotify permissions
scope = 'user-library-read playlist-read-private user-top-read'

# %%
client_id = 'd3f619ebc4e148348b7c292d61418501'
client_secret = 'c95e83acb02d47df800c4d21147f666a'
redirect_uri = 'http://127.0.0.1:8000/songselect'

# %%
# Initiate API Query Object
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,client_secret=client_secret, redirect_uri=redirect_uri,scope=scope))

# %%
sp.search('Beyonce')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Beyonce&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/52kvZcbEDm0v2kWZQXjuuA'},
#      'href': 'https://api.spotify.com/v1/albums/52kvZcbEDm0v2kWZQXjuuA',
#      'id': '52kvZcbEDm0v2kWZQXjuuA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273af6b2fca3b6e24612a5fe5d8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02af6b2fca3b6e24612a5fe5d8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851af6b2fca3b6e24612a5fe5d8',
#        'width': 64}],
#      'name': 'Perfect Duet (Ed Sheeran & Beyoncé)',
#      'release_date': '2017-11-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:52kvZcbEDm0v2kWZQXjuuA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 259550,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1701196'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1bhUWB0zJMIKr9yVPrkEuI'},
#     'href': 'https://api.spotify.com/v1/tracks/1bhUWB0zJMIKr9yVPrkEuI',
#     'id': '1bhUWB0zJMIKr9yVPrkEuI',
#     'is_local': False,
#     'name': 'Perfect Duet (Ed Sheeran & Beyoncé)',
#     'popularity': 83,
#     'preview_url': 'https://p.scdn.co/mp3-preview/65ee4bf5cfdc8f2cd9cc1742f9d4b2ba10c83b2f?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1bhUWB0zJMIKr9yVPrkEuI'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0g9HIUiT4bk4Yz3woGtI0l'},
#        'href': 'https://api.spotify.com/v1/artists/0g9HIUiT4bk4Yz3woGtI0l',
#        'id': '0g9HIUiT4bk4Yz3woGtI0l',
#        'name': 'L A Pa$to',
#        'type': 'artist',
#        'uri': 'spotify:artist:0g9HIUiT4bk4Yz3woGtI0l'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/01VoxYjS7zdtjl1S7CXuW9'},
#      'href': 'https://api.spotify.com/v1/albums/01VoxYjS7zdtjl1S7CXuW9',
#      'id': '01VoxYjS7zdtjl1S7CXuW9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273421ce781fbd21431e9d9053d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02421ce781fbd21431e9d9053d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851421ce781fbd21431e9d9053d',
#        'width': 64}],
#      'name': 'Beyonce Freestyle',
#      'release_date': '2021-11-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:01VoxYjS7zdtjl1S7CXuW9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0g9HIUiT4bk4Yz3woGtI0l'},
#       'href': 'https://api.spotify.com/v1/artists/0g9HIUiT4bk4Yz3woGtI0l',
#       'id': '0g9HIUiT4bk4Yz3woGtI0l',
#       'name': 'L A Pa$to',
#       'type': 'artist',
#       'uri': 'spotify:artist:0g9HIUiT4bk4Yz3woGtI0l'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 89859,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZPLR2173783'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6fM4jo5sNoZ9mBNxyf5keH'},
#     'href': 'https://api.spotify.com/v1/tracks/6fM4jo5sNoZ9mBNxyf5keH',
#     'id': '6fM4jo5sNoZ9mBNxyf5keH',
#     'is_local': False,
#     'name': 'Beyonce Freestyle',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fb7a0e252f4f3ca9d1dceb6fef51e99eeb01f250?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6fM4jo5sNoZ9mBNxyf5keH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6oxVabMIqCMJRYN1GqR3Vf'},
#      'href': 'https://api.spotify.com/v1/albums/6oxVabMIqCMJRYN1GqR3Vf',
#      'id': '6oxVabMIqCMJRYN1GqR3Vf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345680a4a57c97894490a01c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245680a4a57c97894490a01c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145680a4a57c97894490a01c1',
#        'width': 64}],
#      'name': 'Dangerously In Love',
#      'release_date': '2003-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:6oxVabMIqCMJRYN1GqR3Vf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY-Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 236133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10305425'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5IVuqXILoxVWvWEPm82Jxr'},
#     'href': 'https://api.spotify.com/v1/tracks/5IVuqXILoxVWvWEPm82Jxr',
#     'id': '5IVuqXILoxVWvWEPm82Jxr',
#     'is_local': False,
#     'name': 'Crazy In Love (feat. Jay-Z)',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ce8ace0ec425840416be78db07cf50dd331eed4f?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5IVuqXILoxVWvWEPm82Jxr'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4tyEy1BUd2ZMgT3qP70T3F'},
#      'href': 'https://api.spotify.com/v1/albums/4tyEy1BUd2ZMgT3qP70T3F',
#      'id': '4tyEy1BUd2ZMgT3qP70T3F',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d7ffdc64b1933f01a392470',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d7ffdc64b1933f01a392470',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d7ffdc64b1933f01a392470',
#        'width': 64}],
#      'name': 'HOMECOMING: THE LIVE ALBUM',
#      'release_date': '2019-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:4tyEy1BUd2ZMgT3qP70T3F'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 240776,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11902768'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3FUXVbi9ugVUqJ3rPrfd2G'},
#     'href': 'https://api.spotify.com/v1/tracks/3FUXVbi9ugVUqJ3rPrfd2G',
#     'id': '3FUXVbi9ugVUqJ3rPrfd2G',
#     'is_local': False,
#     'name': 'Before I Let Go - Homecoming Live Bonus Track',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2111543f31afbc81a5071dcefc454b98f04a08da?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 39,
#     'type': 'track',
#     'uri': 'spotify:track:3FUXVbi9ugVUqJ3rPrfd2G'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BF',
#       'BG',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JM',
#       'JP',
#       'KE',
#       'KG',
#       'KI',
#       'KM',
#       'KN',
#       'KZ',
#       'LC',
#       'LI',
#       'LR',
#       'LS',
#       'LT',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NR',
#       'NZ',
#       'PA',
#       'PE',
#       'PG',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SB',
#       'SC',
#       'SE',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TJ',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/39P7VD7qlg3Z0ltq60eHp7'},
#      'href': 'https://api.spotify.com/v1/albums/39P7VD7qlg3Z0ltq60eHp7',
#      'id': '39P7VD7qlg3Z0ltq60eHp7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273801c4d205accdba0a468a10b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02801c4d205accdba0a468a10b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851801c4d205accdba0a468a10b',
#        'width': 64}],
#      'name': 'I AM...SASHA FIERCE',
#      'release_date': '2008-11-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:39P7VD7qlg3Z0ltq60eHp7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BF',
#      'BG',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KI',
#      'KM',
#      'KN',
#      'KZ',
#      'LC',
#      'LI',
#      'LR',
#      'LS',
#      'LT',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TJ',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 261640,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10804556'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4JehYebiI9JE8sR8MisGVb'},
#     'href': 'https://api.spotify.com/v1/tracks/4JehYebiI9JE8sR8MisGVb',
#     'id': '4JehYebiI9JE8sR8MisGVb',
#     'is_local': False,
#     'name': 'Halo',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3c97985f3736fab6d4abcd2067f346a9b30955fa?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4JehYebiI9JE8sR8MisGVb'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/181bsRPaVXVlUKXrxwZfHK'},
#        'href': 'https://api.spotify.com/v1/artists/181bsRPaVXVlUKXrxwZfHK',
#        'id': '181bsRPaVXVlUKXrxwZfHK',
#        'name': 'Megan Thee Stallion',
#        'type': 'artist',
#        'uri': 'spotify:artist:181bsRPaVXVlUKXrxwZfHK'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6M4VOF1ExBRii1x20Pk0GR'},
#      'href': 'https://api.spotify.com/v1/albums/6M4VOF1ExBRii1x20Pk0GR',
#      'id': '6M4VOF1ExBRii1x20Pk0GR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cd613f53a22b92b14694943c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cd613f53a22b92b14694943c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cd613f53a22b92b14694943c',
#        'width': 64}],
#      'name': 'Savage Remix (feat. Beyoncé)',
#      'release_date': '2020-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6M4VOF1ExBRii1x20Pk0GR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/181bsRPaVXVlUKXrxwZfHK'},
#       'href': 'https://api.spotify.com/v1/artists/181bsRPaVXVlUKXrxwZfHK',
#       'id': '181bsRPaVXVlUKXrxwZfHK',
#       'name': 'Megan Thee Stallion',
#       'type': 'artist',
#       'uri': 'spotify:artist:181bsRPaVXVlUKXrxwZfHK'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242000,
#     'explicit': True,
#     'external_ids': {'isrc': 'QMCE32000145'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5v4GgrXPMghOnBBLmveLac'},
#     'href': 'https://api.spotify.com/v1/tracks/5v4GgrXPMghOnBBLmveLac',
#     'id': '5v4GgrXPMghOnBBLmveLac',
#     'is_local': False,
#     'name': 'Savage Remix (feat. Beyoncé)',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/82b86052d5cfa3802d47b4ee63036d2bfeb86525?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5v4GgrXPMghOnBBLmveLac'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BF',
#       'BG',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JM',
#       'JP',
#       'KE',
#       'KG',
#       'KI',
#       'KM',
#       'KN',
#       'KZ',
#       'LC',
#       'LI',
#       'LR',
#       'LS',
#       'LT',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NR',
#       'NZ',
#       'PA',
#       'PE',
#       'PG',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SB',
#       'SC',
#       'SE',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TJ',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/39P7VD7qlg3Z0ltq60eHp7'},
#      'href': 'https://api.spotify.com/v1/albums/39P7VD7qlg3Z0ltq60eHp7',
#      'id': '39P7VD7qlg3Z0ltq60eHp7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273801c4d205accdba0a468a10b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02801c4d205accdba0a468a10b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851801c4d205accdba0a468a10b',
#        'width': 64}],
#      'name': 'I AM...SASHA FIERCE',
#      'release_date': '2008-11-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:39P7VD7qlg3Z0ltq60eHp7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BF',
#      'BG',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KI',
#      'KM',
#      'KN',
#      'KZ',
#      'LC',
#      'LI',
#      'LR',
#      'LS',
#      'LT',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TJ',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 2,
#     'duration_ms': 200613,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10804755'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1CxebLetK1dLJvRXlgHGXg'},
#     'href': 'https://api.spotify.com/v1/tracks/1CxebLetK1dLJvRXlgHGXg',
#     'id': '1CxebLetK1dLJvRXlgHGXg',
#     'is_local': False,
#     'name': 'Diva',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e97d79b76bcb980f9701567b0832d2ebea780a6a?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1CxebLetK1dLJvRXlgHGXg'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7dK54iZuOxXFarGhXwEXfF'},
#      'href': 'https://api.spotify.com/v1/albums/7dK54iZuOxXFarGhXwEXfF',
#      'id': '7dK54iZuOxXFarGhXwEXfF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27389992f4d7d4ab94937bf9e23',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0289992f4d7d4ab94937bf9e23',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485189992f4d7d4ab94937bf9e23',
#        'width': 64}],
#      'name': 'Lemonade',
#      'release_date': '2016-04-23',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7dK54iZuOxXFarGhXwEXfF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 206080,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM11603186'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6g0Orsxv6glTJCt4cHsRsQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6g0Orsxv6glTJCt4cHsRsQ',
#     'id': '6g0Orsxv6glTJCt4cHsRsQ',
#     'is_local': False,
#     'name': 'Formation',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/470cfb59470d8313dc99634c2845170b56a8762e?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:6g0Orsxv6glTJCt4cHsRsQ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BF',
#       'BG',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JM',
#       'JP',
#       'KE',
#       'KG',
#       'KI',
#       'KM',
#       'KN',
#       'KZ',
#       'LC',
#       'LI',
#       'LR',
#       'LS',
#       'LT',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NO',
#       'NR',
#       'NZ',
#       'PA',
#       'PE',
#       'PG',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SB',
#       'SC',
#       'SE',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TJ',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/39P7VD7qlg3Z0ltq60eHp7'},
#      'href': 'https://api.spotify.com/v1/albums/39P7VD7qlg3Z0ltq60eHp7',
#      'id': '39P7VD7qlg3Z0ltq60eHp7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273801c4d205accdba0a468a10b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02801c4d205accdba0a468a10b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851801c4d205accdba0a468a10b',
#        'width': 64}],
#      'name': 'I AM...SASHA FIERCE',
#      'release_date': '2008-11-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:39P7VD7qlg3Z0ltq60eHp7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BF',
#      'BG',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KI',
#      'KM',
#      'KN',
#      'KZ',
#      'LC',
#      'LI',
#      'LR',
#      'LS',
#      'LT',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NO',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TJ',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 2,
#     'duration_ms': 208066,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10804756'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3WFswNYDLfjj9Cg0Y1sNyW'},
#     'href': 'https://api.spotify.com/v1/tracks/3WFswNYDLfjj9Cg0Y1sNyW',
#     'id': '3WFswNYDLfjj9Cg0Y1sNyW',
#     'is_local': False,
#     'name': 'Sweet Dreams',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c76787675800fb0aeb087fae9506380631def9df?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3WFswNYDLfjj9Cg0Y1sNyW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1gIC63gC3B7o7FfpPACZQJ'},
#      'href': 'https://api.spotify.com/v1/albums/1gIC63gC3B7o7FfpPACZQJ',
#      'id': '1gIC63gC3B7o7FfpPACZQJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ff5429125128b43572dbdccd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ff5429125128b43572dbdccd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ff5429125128b43572dbdccd',
#        'width': 64}],
#      'name': '4',
#      'release_date': '2011-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1gIC63gC3B7o7FfpPACZQJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 267413,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11102908'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1z6WtY7X4HQJvzxC4UgkSf'},
#     'href': 'https://api.spotify.com/v1/tracks/1z6WtY7X4HQJvzxC4UgkSf',
#     'id': '1z6WtY7X4HQJvzxC4UgkSf',
#     'is_local': False,
#     'name': 'Love On Top',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9a7675cc7f71c524af1397cf1675b61a8fbc74ed?cid=d3f619ebc4e148348b7c292d61418501',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1z6WtY7X4HQJvzxC4UgkSf'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Beyonce&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 6541}}

# %%
# Initial check if API is working as intended
sp.current_user()
# Out:
# {'display_name': 'ericwyeah',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/ericwyeah'},
#  'followers': {'href': None, 'total': 15},
#  'href': 'https://api.spotify.com/v1/users/ericwyeah',
#  'id': 'ericwyeah',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab6775700000ee850608af8b68d924da27603720',
#    'width': None}],
#  'type': 'user',
#  'uri': 'spotify:user:ericwyeah'}

# %% [markdown]
# ### Step 2: Pull Current User's Top Tracks
#
# TODO: Explain Spotify Top Tracks designation process (how does spotify determine what someone's top tracks are?)

# %%
top_query = sp.current_user_top_tracks(limit=20, offset=0, time_range='medium_term')['items']

# %%
top_query[0]['album']['images'][-1]
# Out:
# {'height': 64,
#  'url': 'https://i.scdn.co/image/ab67616d00004851c0d5f377e45b39d3ea7c7b67',
#  'width': 64}

# %%
# Create function to retrieve list of top tracks for current user
def get_top_tracks():
    top_tracks = []

    top_query = sp.current_user_top_tracks(limit=20, offset=0, time_range='medium_term')['items']
    for entry in top_query:
        artists = []
        for artist in entry['artists']:
            artists.append(artist['name'])
        top_tracks.append({'artists': artists, 'track_id': entry['id'], 'name': entry['name'], 'preview_url': entry['preview_url'], 'image': entry['album']['images'][-1]['url']})
    
    for track in top_tracks:
        if len(track['artists']) > 1:
            track['display_info'] = track['name'] + ' by ' + ' and '.join(track['artists'])
        else:
            track['display_info'] = track['name'] + ' by ' + track['artists'][0]
    
    return top_tracks

# %%
top_tracks = get_top_tracks()
top_tracks[0]
# Out:
# {'artists': ['Magic Man'],
#  'track_id': '4EaO2XR7gWaHq8DW7nu1iY',
#  'name': 'Paris',
#  'preview_url': 'https://p.scdn.co/mp3-preview/5d6ff173f44b7efea949d27adf931fc541f384c9?cid=d3f619ebc4e148348b7c292d61418501',
#  'image': 'https://i.scdn.co/image/ab67616d00004851c0d5f377e45b39d3ea7c7b67',
#  'display_info': 'Paris by Magic Man'}

# %%
# Create function to format tracks to include track name and artist name
def format_tracks(track_list):
    display_text = []

    for track in track_list:
        if len(track['artists']) > 1:
            display_text.append(track['name'] + ' by ' + ' and '.join(track['artists']))
        else:
            display_text.append(track['name'] + ' by ' + track['artists'][0])
    return display_text

# %%
format_tracks(top_tracks)[0]
# Out:
# 'Paris by Magic Man'

# %% [markdown]
# ### Step 3: Test Search Functionality (for implementation in web app)
#
# TODO: Say Stuff

# %%
# Example query of Lizzo
query = 'Lizzo'

# %%
# Create function to return list of search results based on search query
def search_tracks(query):
    search_results = sp.search(q=query, type='track,artist')
    search_tracks = []

    for entry in search_results['tracks']['items']:
        artists = []
        for artist in entry['artists']:
            artists.append(artist['name'])
        search_tracks.append({'artists': artists, 'track_id': entry['id'], 'name': entry['name'], 'preview_url': entry['preview_url'], 'image': entry['album']['images'][-1]['url']})
    return search_tracks

# %%
search_results = search_tracks(query)
search_results[0]
# Out:
# {'artists': ['Lizzo', 'Cardi B'],
#  'track_id': '6KgtcmCF9Ky68XC7ezxl3s',
#  'name': 'Rumors (feat. Cardi B)',
#  'preview_url': 'https://p.scdn.co/mp3-preview/252a7be97bc9172a9aca8552abf964783bc24cec?cid=d3f619ebc4e148348b7c292d61418501',
#  'image': 'https://i.scdn.co/image/ab67616d00004851324290e5b99a797b99e247bb'}

# %%
# Format tracks to include track name and artist name
display_text = []

for track in search_tracks:
    
    if len(track['artists']) > 1:
        display_text.append(track['name'] + ' by ' + ' and '.join(track['artists']))
    else:
        display_text.append(track['name'] + ' by ' + track['artists'][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27200/3533838421.py in <module>
#       2 display_text = []
#       3
# ----> 4 for track in search_tracks:
#       5
#       6     if len(track['artists']) > 1:
#
# TypeError: 'function' object is not iterable

# %%
format_tracks(search_results)[0]
# Out:
# 'Rumors (feat. Cardi B) by Lizzo and Cardi B'

# %% [markdown]
# ### Step 4: Test Retrieving Current User's Playlists and their Tracks (for implementation in web app)
#
# TODO: Say Stuff

# %%
# Use Spotify API Object to pull current user's playlists
playlists = sp.current_user_playlists(limit=50, offset=0)['items']

# %%
# Format playlist information for user viewing
playlist_display = [entry['name'] + ' by ' + entry['owner']['display_name'] for entry in playlists]

# %%
playlist_display[0]
# Out:
# 'My Playlist by ericwyeah'

# %%
# Create list of current user's playlists
def query_playlists():
    playlists_list = []
    playlists = sp.current_user_playlists(limit=50, offset=0)['items']
    for playlist in playlists:
        playlists_list.append({'name': playlist['name'], 'display_info': (playlist['name'] + ' by ' + playlist['owner']['display_name']), 'owner': playlist['owner']['display_name'], 'playlist_id': playlist['id'], 'image': playlist['images'][-1]['url']})
    return playlists_list

# Format user's playlists
def format_playlists(playlists_list):
    formatted_playlists = [entry['name'] + ' by ' + entry['owner'] for entry in playlists_list]
    return formatted_playlists

# %%
playlist_list = query_playlists()
format_playlists(playlist_list)[0]
# Out:
# 'My Playlist by ericwyeah'

# %%
playlist_list[0]
# Out:
# {'name': 'My Playlist',
#  'display_info': 'My Playlist by ericwyeah',
#  'owner': 'ericwyeah',
#  'playlist_id': '75fV6pcpgTv0xLOadc343I',
#  'image': 'https://i.scdn.co/image/ab67616d0000b2733a2cc6c5cdd9f07a95efa51b'}

# %%
# Create function that returns list of tracks in specified playlist
def tracks_in_playlist(username, playlist_id):
    playlist_tracks = []

    playlist_query = sp.user_playlist_tracks(username, playlist_id)['items']
    for entry in playlist_query:
        artists = []
        for artist in entry['track']['artists']:
            artists.append(artist['name'])

        playlist_tracks.append({'artists': artists, 'track_id': entry['track']['id'], 'name': entry['track']['name'], 'preview_url': entry['track']['preview_url'], 'image': entry['track']['album']['images'][-1]['url']})
    return playlist_tracks

# %%
sp.search(q='My Playlist',type='playlist')
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=My+Playlist&type=playlist&offset=0&limit=10',
#   'items': [{'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/75fV6pcpgTv0xLOadc343I'},
#     'href': 'https://api.spotify.com/v1/playlists/75fV6pcpgTv0xLOadc343I',
#     'id': '75fV6pcpgTv0xLOadc343I',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733a2cc6c5cdd9f07a95efa51b',
#       'width': 640}],
#     'name': 'My Playlist',
#     'owner': {'display_name': 'ericwyeah',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/ericwyeah'},
#      'href': 'https://api.spotify.com/v1/users/ericwyeah',
#      'id': 'ericwyeah',
#      'type': 'user',
#      'uri': 'spotify:user:ericwyeah'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MywzMWQ4MDkxOGE2YjAxNDkwMjExZDFjNWNiMmVhZjM5YTEwMDc0Y2Yx',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/75fV6pcpgTv0xLOadc343I/tracks',
#      'total': 1},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:75fV6pcpgTv0xLOadc343I'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7DiY4JNu6zCz49YALH9yVB'},
#     'href': 'https://api.spotify.com/v1/playlists/7DiY4JNu6zCz49YALH9yVB',
#     'id': '7DiY4JNu6zCz49YALH9yVB',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebb2cfa683e443975a21ef71904',
#       'width': None}],
#     'name': 'my playlist',
#     'owner': {'display_name': 'ale',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/alego5910'},
#      'href': 'https://api.spotify.com/v1/users/alego5910',
#      'id': 'alego5910',
#      'type': 'user',
#      'uri': 'spotify:user:alego5910'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzI3LGUxYjNlNDdhOWIwMzdiMWI2ZjhmOWIwODZjNDFkZTNmNTEwYWEwYjc=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7DiY4JNu6zCz49YALH9yVB/tracks',
#      'total': 290},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7DiY4JNu6zCz49YALH9yVB'},
#    {'collaborative': False,
#     'description': 'Time for Your Summer Rewind! We’ve made you a new playlist featuring your old summer favorites.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1CAo3PwbA2OWVB'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1CAo3PwbA2OWVB',
#     'id': '37i9dQZF1CAo3PwbA2OWVB',
#     'images': [{'height': None,
#       'url': 'https://lineup-images.scdn.co/summer-rewind-2020_LARGE-en.jpg',
#       'width': None}],
#     'name': 'Your Summer Rewind',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjY1NDgxNzAsMDAwMDAwMDAxOTU2ZmU4Y2RmNzcwYzcxMGFiYzU4OWE0YTM4ZmNlNA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1CAo3PwbA2OWVB/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1CAo3PwbA2OWVB'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2fhS32N61HmQ88lrHf6Rzg'},
#     'href': 'https://api.spotify.com/v1/playlists/2fhS32N61HmQ88lrHf6Rzg',
#     'id': '2fhS32N61HmQ88lrHf6Rzg',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732f44aec83b20e40f3baef73cab67616d0000b27331aafa752187cb0284307200ab67616d0000b2736ca5c90113b30c3c43ffb8f4ab67616d0000b27371af28545729f60b3eca66f7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732f44aec83b20e40f3baef73cab67616d0000b27331aafa752187cb0284307200ab67616d0000b2736ca5c90113b30c3c43ffb8f4ab67616d0000b27371af28545729f60b3eca66f7',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732f44aec83b20e40f3baef73cab67616d0000b27331aafa752187cb0284307200ab67616d0000b2736ca5c90113b30c3c43ffb8f4ab67616d0000b27371af28545729f60b3eca66f7',
#       'width': 60}],
#     'name': 'My Playlist #1',
#     'owner': {'display_name': 'DECAY',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/rmhxr444y4xlexk4ax3flho2u'},
#      'href': 'https://api.spotify.com/v1/users/rmhxr444y4xlexk4ax3flho2u',
#      'id': 'rmhxr444y4xlexk4ax3flho2u',
#      'type': 'user',
#      'uri': 'spotify:user:rmhxr444y4xlexk4ax3flho2u'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NyxkMDY3YjVlYmQwY2VkMWIxMzg2NWQxOTg1ZDBhNzM4NjZlYTcwOWFh',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2fhS32N61HmQ88lrHf6Rzg/tracks',
#      'total': 6},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2fhS32N61HmQ88lrHf6Rzg'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2rYGLZqiH6g5BBTkE7L6yX'},
#     'href': 'https://api.spotify.com/v1/playlists/2rYGLZqiH6g5BBTkE7L6yX',
#     'id': '2rYGLZqiH6g5BBTkE7L6yX',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273635b3ab0f7ecda463021ccddab67616d0000b273801b6025f12b3ffb05878bf4ab67616d0000b2739cbbbdd15ff65aaab9a611b0ab67616d0000b273c1c622a960dd41a37fcea46f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273635b3ab0f7ecda463021ccddab67616d0000b273801b6025f12b3ffb05878bf4ab67616d0000b2739cbbbdd15ff65aaab9a611b0ab67616d0000b273c1c622a960dd41a37fcea46f',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273635b3ab0f7ecda463021ccddab67616d0000b273801b6025f12b3ffb05878bf4ab67616d0000b2739cbbbdd15ff65aaab9a611b0ab67616d0000b273c1c622a960dd41a37fcea46f',
#       'width': 60}],
#     'name': 'My Playlist',
#     'owner': {'display_name': 'c.jesse_21',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/c.jesse_21'},
#      'href': 'https://api.spotify.com/v1/users/c.jesse_21',
#      'id': 'c.jesse_21',
#      'type': 'user',
#      'uri': 'spotify:user:c.jesse_21'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTQ3LDMxOThlNDZkYTEwMzYyNzA4YjY5YzQxNjYwYzRiYjUyMGZlMTA0YzY=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2rYGLZqiH6g5BBTkE7L6yX/tracks',
#      'total': 144},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2rYGLZqiH6g5BBTkE7L6yX'},
#    {'collaborative': False,
#     'description': "The hip-hop playlist that's a whole mood. Art By Laci Jordan; Cover: Erica Banks\n",
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6GwdWRQMQpq'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6GwdWRQMQpq',
#     'id': '37i9dQZF1DX6GwdWRQMQpq',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003c32c28372835af7e7e9dbed2',
#       'width': None}],
#     'name': "Feelin' Myself",
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY0MjEzNjQwMCwwMDAwMDQ3MzAwMDAwMTdlNTZmNGYxNTcwMDAwMDE3ZTU1ZjRmMTAw',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6GwdWRQMQpq/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX6GwdWRQMQpq'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1JqljqumKmidtlcSSuya4r'},
#     'href': 'https://api.spotify.com/v1/playlists/1JqljqumKmidtlcSSuya4r',
#     'id': '1JqljqumKmidtlcSSuya4r',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27327d9d4ff05270bd0c8d7ac7cab67616d0000b273283052004669f577df1a7e5dab67616d0000b273e340c446f058ffb5febe7b76ab67616d0000b273f791b6aeb2a465b82adb284a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27327d9d4ff05270bd0c8d7ac7cab67616d0000b273283052004669f577df1a7e5dab67616d0000b273e340c446f058ffb5febe7b76ab67616d0000b273f791b6aeb2a465b82adb284a',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27327d9d4ff05270bd0c8d7ac7cab67616d0000b273283052004669f577df1a7e5dab67616d0000b273e340c446f058ffb5febe7b76ab67616d0000b273f791b6aeb2a465b82adb284a',
#       'width': 60}],
#     'name': 'My Playlist #2',
#     'owner': {'display_name': 'vstaples',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/v4rkey3tbxaje4s6gl4kkadeq'},
#      'href': 'https://api.spotify.com/v1/users/v4rkey3tbxaje4s6gl4kkadeq',
#      'id': 'v4rkey3tbxaje4s6gl4kkadeq',
#      'type': 'user',
#      'uri': 'spotify:user:v4rkey3tbxaje4s6gl4kkadeq'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTMwLGJjYTJiODdlOWY5YzVjMGFjYTYwZWUzNjdhYjdlZTJmNmNlOWRhYzc=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1JqljqumKmidtlcSSuya4r/tracks',
#      'total': 25},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1JqljqumKmidtlcSSuya4r'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6sQ3vyY9FVGoFVc28NG3C9'},
#     'href': 'https://api.spotify.com/v1/playlists/6sQ3vyY9FVGoFVc28NG3C9',
#     'id': '6sQ3vyY9FVGoFVc28NG3C9',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273145dfe10bf464ccce2b006f4ab67616d0000b27323c6bf9a2c1b503e5ae8a6c4ab67616d0000b273567121d8cddb25d1f5ff9650ab67616d0000b27364afd6879102d03460bd3ad9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273145dfe10bf464ccce2b006f4ab67616d0000b27323c6bf9a2c1b503e5ae8a6c4ab67616d0000b273567121d8cddb25d1f5ff9650ab67616d0000b27364afd6879102d03460bd3ad9',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273145dfe10bf464ccce2b006f4ab67616d0000b27323c6bf9a2c1b503e5ae8a6c4ab67616d0000b273567121d8cddb25d1f5ff9650ab67616d0000b27364afd6879102d03460bd3ad9',
#       'width': 60}],
#     'name': 'My playlist 😝',
#     'owner': {'display_name': 'Magda Zavala',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/22hcjokx2utqyx7npugbowyuq'},
#      'href': 'https://api.spotify.com/v1/users/22hcjokx2utqyx7npugbowyuq',
#      'id': '22hcjokx2utqyx7npugbowyuq',
#      'type': 'user',
#      'uri': 'spotify:user:22hcjokx2utqyx7npugbowyuq'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzE2LDA1ODFjNzYyYzljMzQ5NjgzMWYxNGZiZTMxZGUzYThmYzFmYmJkODE=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6sQ3vyY9FVGoFVc28NG3C9/tracks',
#      'total': 312},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6sQ3vyY9FVGoFVc28NG3C9'},
#    {'collaborative': False,
#     'description': 'All your favorite tracks from Bridgerton. Flawless my dear!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5Hl0iWtr5b3'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5Hl0iWtr5b3',
#     'id': '37i9dQZF1DX5Hl0iWtr5b3',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003cbbb250786a0f331bdc8f273',
#       'width': None}],
#     'name': 'Bridgerton: Official Playlist',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY0MTMwOTY0MywwMDAwMDAxMjAwMDAwMTdlMjVhZGEyNjIwMDAwMDE3NzIwNjc3ODli',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5Hl0iWtr5b3/tracks',
#      'total': 34},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX5Hl0iWtr5b3'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/65OxRRTxk5PbtK9jxpq9LG'},
#     'href': 'https://api.spotify.com/v1/playlists/65OxRRTxk5PbtK9jxpq9LG',
#     'id': '65OxRRTxk5PbtK9jxpq9LG',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27351b0b0af87a9fc24f963e6a4ab67616d0000b27398392b90e6272a7c529eba12ab67616d0000b2739efda673310de265a2c1cf1fab67616d0000b273d52d8eb3be188231e120dbbd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27351b0b0af87a9fc24f963e6a4ab67616d0000b27398392b90e6272a7c529eba12ab67616d0000b2739efda673310de265a2c1cf1fab67616d0000b273d52d8eb3be188231e120dbbd',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27351b0b0af87a9fc24f963e6a4ab67616d0000b27398392b90e6272a7c529eba12ab67616d0000b2739efda673310de265a2c1cf1fab67616d0000b273d52d8eb3be188231e120dbbd',
#       'width': 60}],
#     'name': 'My Playlist #9',
#     'owner': {'display_name': 'luis5687$',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/luis5687%24'},
#      'href': 'https://api.spotify.com/v1/users/luis5687%24',
#      'id': 'luis5687$',
#      'type': 'user',
#      'uri': 'spotify:user:luis5687%24'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzQxLDE1ZDc5MTU4ZTYzMzIwNzAwYmZlNTM4YmMxYjQ1NTRhODI0ZDUyNWQ=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/65OxRRTxk5PbtK9jxpq9LG/tracks',
#      'total': 274},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:65OxRRTxk5PbtK9jxpq9LG'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=My+Playlist&type=playlist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 1567718}}

# %%
def query_playlist_id(playlist_name, playlist_list):
    return next(item for item in playlist_list if item["name"] == playlist_name)['playlist_id']

# %%
query_playlist_id('My Playlist', playlist_list)
# Out:
# '75fV6pcpgTv0xLOadc343I'

# %%
# Name of first track in playlist ;)
tracks_in_playlist('ericwyeah', playlist_list[0]['playlist_id'])[0]['name']
# Out:
# 'Hello World'

# %% [markdown]
# ### Step 5: Create a Function to Evaluate Tracks' Features
#
# TODO: Say Stuff

# %%
def get_track_features(track_ids):
    audio_features = sp.audio_features(track_ids)
    return audio_features

# %%
top_tracks_ids = [entry['track_id'] for entry in top_tracks]
top_track_features = get_track_features(top_tracks_ids)

# %%
def average_features(list_of_features):
    numeric_features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']
    numeric_values = [{ your_key: dict_entry[your_key] for your_key in numeric_features } for dict_entry in list_of_features]
    
    counter = collections.Counter()
    for d in numeric_values: 
        counter.update(d)
        
    return {k: v / len(list_of_features) for k, v in dict(counter).items()}

# %%
average_features(top_track_features)
# Out:
# {'acousticness': 0.23316649999999997,
#  'danceability': 0.55505,
#  'energy': 0.6758,
#  'instrumentalness': 0.009247315,
#  'liveness': 0.138085,
#  'loudness': -6.33005,
#  'speechiness': 0.07387,
#  'valence': 0.4647999999999999,
#  'tempo': 114.1386}

# %% [markdown]
# ### Step 6: Identify the Average Features of Different Spotify Genres
#
# Spotify's Today's Top Hits Playlist is a collection of the current top Pop hits. In order to determine the average feature values of the Pop genre, we used this playlist as reference.

# %%
def playlist_average_features(playlist_id):
    tracks = tracks_in_playlist('ericwyeah',playlist_id)
    track_ids = [entry['track_id'] for entry in tracks]
    tracks_features = get_track_features(track_ids)
    return average_features(tracks_features)

# %% [markdown]
# #### POP

# %%
todays_top_hits_id = '37i9dQZF1DXcBWIGoYBM5M'

# %%
pop_hits = tracks_in_playlist('ericwyeah',todays_top_hits_id)

# %%
pop_hits[0]
# Out:
# {'artists': ['GAYLE'],
#  'track_id': '4fouWK6XVHhzl78KzQ1UjL',
#  'name': 'abcdefu',
#  'preview_url': 'https://p.scdn.co/mp3-preview/25a618c8bbf72ac750ab2024c8b987820ecc1cd1?cid=d3f619ebc4e148348b7c292d61418501',
#  'image': 'https://i.scdn.co/image/ab67616d0000485102d82cf34fefe6736718acd1'}

# %%
pop_ids = [entry['track_id'] for entry in pop_hits]

# %%
pop_features = get_track_features(pop_ids)

# %%
average_features(pop_features)
# Out:
# {'acousticness': 0.22150759999999994,
#  'danceability': 0.6958200000000001,
#  'energy': 0.63538,
#  'instrumentalness': 0.0013480440000000003,
#  'liveness': 0.180602,
#  'loudness': -6.365960000000001,
#  'speechiness': 0.09286200000000003,
#  'valence': 0.5238920000000002,
#  'tempo': 120.58756000000002}

# %% [markdown]
# ##### Classical

# %%
classical_essentials_id = '37i9dQZF1DWWEJlAGA9gs0'

# %%
classical_essentials = tracks_in_playlist('ericwyeah',classical_essentials_id)

# %%
classical_essentials[0]
# Out:
# {'artists': ['Johann Sebastian Bach', 'Lang Lang'],
#  'track_id': '4SFBV7SRNG2e2kyL1F6kjU',
#  'name': 'The Well-Tempered Clavier: Book 1, BWV 846-869: I. Prelude in C Major, BWV 846',
#  'preview_url': None,
#  'image': 'https://i.scdn.co/image/ab67616d00004851bf4b533ee6e9634a6fcd8882'}

# %%
classical_ids = [entry['track_id'] for entry in classical_essentials]

# %%
classical_features = get_track_features(classical_ids)

# %%
average_features(classical_features)
# Out:
# {'acousticness': 0.9239100000000002,
#  'danceability': 0.2489889999999999,
#  'energy': 0.09592900000000001,
#  'instrumentalness': 0.7452943240000001,
#  'liveness': 0.12242199999999999,
#  'loudness': -23.397980000000004,
#  'speechiness': 0.04372200000000001,
#  'valence': 0.12267999999999998,
#  'tempo': 99.69890000000001}

# %% [markdown]
# ##### EDM

# %%
edm_hits_id = '37i9dQZF1DX3Kdv0IChEm9'

# %%
edm_hits = tracks_in_playlist('ericwyeah',edm_hits_id)

# %%
edm_hits[0]
# Out:
# {'artists': ['Kygo', 'Kodaline'],
#  'track_id': '2Vhd5uZB4brKHmM0MNxkZo',
#  'name': 'Raging (feat. Kodaline)',
#  'preview_url': 'https://p.scdn.co/mp3-preview/5990c6b9266413c300d7b36d17248d891504e1ab?cid=d3f619ebc4e148348b7c292d61418501',
#  'image': 'https://i.scdn.co/image/ab67616d0000485135590cb9280d5a1f5221ae1a'}

# %%
edm_ids = [entry['track_id'] for entry in edm_hits]

# %%
edm_features = get_track_features(edm_ids)

# %%
def temp(list_of_features):
    numeric_features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']
    display()
    numeric_values = [{ your_key: dict_entry[your_key] for your_key in numeric_features } for dict_entry in list_of_features]
    
    counter = collections.Counter()
    for d in numeric_values: 
        counter.update(d)
        
    return {k: v / len(list_of_features) for k, v in dict(counter).items()}

# %%
temp(edm_features)
# Out:
# {'acousticness': 0.11803159999999997,
#  'danceability': 0.6192000000000001,
#  'energy': 0.7714833333333335,
#  'instrumentalness': 0.026072740833333333,
#  'liveness': 0.21089666666666668,
#  'loudness': -5.099099999999999,
#  'speechiness': 0.05259500000000002,
#  'valence': 0.4325233333333333,
#  'tempo': 121.16761666666665}

# %% [markdown]
# ##### Indie

# %%
indie_id = '37i9dQZF1DX26DKvjp0s9M'

# %%
playlist_average_features(indie_id)
# Out:
# {'acousticness': 0.245093796,
#  'danceability': 0.5536,
#  'energy': 0.6521400000000003,
#  'instrumentalness': 0.08273723770000001,
#  'liveness': 0.17088599999999998,
#  'loudness': -7.147670000000002,
#  'speechiness': 0.045124999999999985,
#  'valence': 0.468014,
#  'tempo': 120.31647}

# %% [markdown]
# ##### Soft Pop

# %%
soft_pop_id = '37i9dQZF1DWTwnEm1IYyoj'

# %%
playlist_average_features(soft_pop_id)
# Out:
# {'acousticness': 0.33000749999999995,
#  'danceability': 0.5815800000000002,
#  'energy': 0.5568550000000002,
#  'instrumentalness': 0.0005572250000000001,
#  'liveness': 0.13098099999999996,
#  'loudness': -6.761510000000002,
#  'speechiness': 0.052465000000000005,
#  'valence': 0.40887000000000007,
#  'tempo': 114.90280999999997}

# %% [markdown]
# ##### R & B

# %%
r_and_b_id = '37i9dQZF1DX4SBhb3fqCJd'

# %%
playlist_average_features(r_and_b_id)
# Out:
# {'acousticness': 0.27255300000000005,
#  'danceability': 0.6129999999999999,
#  'energy': 0.5653600000000001,
#  'instrumentalness': 0.001224497,
#  'liveness': 0.185966,
#  'loudness': -7.36042,
#  'speechiness': 0.10812399999999998,
#  'valence': 0.4450159999999999,
#  'tempo': 111.85530000000003}

# %% [markdown]
# ##### Hip Hop

# %%
hip_hop_id = '37i9dQZF1DXbkfWVLd8wE3'

# %%
playlist_average_features(hip_hop_id)
# Out:
# {'acousticness': 0.12341976041666665,
#  'danceability': 0.7577083333333331,
#  'energy': 0.7451041666666667,
#  'instrumentalness': 0.003262283854166666,
#  'liveness': 0.20602291666666675,
#  'loudness': -5.638437500000002,
#  'speechiness': 0.22962291666666682,
#  'valence': 0.6421145833333334,
#  'tempo': 109.14435416666662}

# %% [markdown]
# ##### Feelin Myself

# %%
feelin_myself_id = '37i9dQZF1DX6GwdWRQMQpq'

# %%
playlist_average_features(feelin_myself_id)
# Out:
# {'acousticness': 0.12620846000000002,
#  'danceability': 0.8277400000000001,
#  'energy': 0.6111599999999999,
#  'instrumentalness': 0.0144701232,
#  'liveness': 0.19104399999999994,
#  'loudness': -6.675579999999999,
#  'speechiness': 0.22947800000000007,
#  'valence': 0.5526599999999999,
#  'tempo': 118.62462000000001}

# %% [markdown]
# ### Step 7: Putting Everything Together <3
#
# TODO: Write Stuff

# %%
# Formatted Search Results
format_tracks(search_results)

# %%
# Formatted Top Tracks
format_tracks(top_tracks)

# %%
# Formatted Playlist List
format_playlists(playlist_list)

# %%
tracks_in_playlist(sp.current_user()['id'], query_playlist_id('eventually', playlist_list))

# %%
sp.current_user()
